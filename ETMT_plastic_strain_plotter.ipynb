# %%
import numpy as np
import matplotlib.pyplot as plt

#ctrl z is redo
#ctrl y is go forward

# %% [markdown]
# Zr2Nb
# Zry7Nb
# Zry2Nb
# Ti64
# TiSnAl

# %%
Zr2Nb_ND_027=np.loadtxt('ETMT True Stress-Strain Data/027.txt', skiprows=1, delimiter=',', usecols=(3,4,5))
Zr2Nb_ND_025=np.loadtxt('ETMT True Stress-Strain Data/025.txt', skiprows=1, delimiter=',', usecols=(3,4,5))
Zr2Nb_ND_037=np.loadtxt('ETMT True Stress-Strain Data/037.txt', skiprows=1, delimiter=',', usecols=(3,4,5))
Zr2Nb_ND_024=np.loadtxt('ETMT True Stress-Strain Data/024.txt', skiprows=1, delimiter=',', usecols=(3,4,5))
Zr2Nb_ND_028=np.loadtxt('ETMT True Stress-Strain Data/028.txt', skiprows=1, delimiter=',', usecols=(3,4,5))
Zr2Nb_ND_026=np.loadtxt('ETMT True Stress-Strain Data/026.txt', skiprows=1, delimiter=',', usecols=(3,4,5))

Zr2Nb_TD_033=np.loadtxt('ETMT True Stress-Strain Data/033.txt', skiprows=1, delimiter=',', usecols=(3,4,5))
Zr2Nb_TD_034=np.loadtxt('ETMT True Stress-Strain Data/034.txt', skiprows=1, delimiter=',', usecols=(3,4,5))
Zr2Nb_TD_036=np.loadtxt('ETMT True Stress-Strain Data/036.txt', skiprows=1, delimiter=',', usecols=(3,4,5))
Zr2Nb_TD_035=np.loadtxt('ETMT True Stress-Strain Data/035.txt', skiprows=1, delimiter=',', usecols=(3,4,5))
Zr2Nb_TD_044=np.loadtxt('ETMT True Stress-Strain Data/044.txt', skiprows=1, delimiter=',', usecols=(3,4,5))

Zry7Nb_ND_029=np.loadtxt('ETMT True Stress-Strain Data/029.txt', skiprows=1, delimiter=',', usecols=(3,4,5))
Zry7Nb_ND_041=np.loadtxt('ETMT True Stress-Strain Data/041.txt', skiprows=1, delimiter=',', usecols=(3,4,5))
Zry7Nb_ND_030=np.loadtxt('ETMT True Stress-Strain Data/030.txt', skiprows=1, delimiter=',', usecols=(3,4,5))
Zry7Nb_ND_031=np.loadtxt('ETMT True Stress-Strain Data/031.txt', skiprows=1, delimiter=',', usecols=(3,4,5))

Zry7Nb_TD_038=np.loadtxt('ETMT True Stress-Strain Data/038.txt', skiprows=1, delimiter=',', usecols=(3,4,5))
Zry7Nb_TD_039=np.loadtxt('ETMT True Stress-Strain Data/039.txt', skiprows=1, delimiter=',', usecols=(3,4,5))
Zry7Nb_TD_040=np.loadtxt('ETMT True Stress-Strain Data/040.txt', skiprows=1, delimiter=',', usecols=(3,4,5))
Zry7Nb_TD_042=np.loadtxt('ETMT True Stress-Strain Data/042.txt', skiprows=1, delimiter=',', usecols=(3,4,5))
#Zry7Nb_TD_048=np.loadtxt('ETMT True Stress-Strain Data/048.txt', skiprows=1, delimiter=',', usecols=(3,4,5))

Zry2Nb_ND_090=np.loadtxt('ETMT True Stress-Strain Data/090.txt', skiprows=1, delimiter=',', usecols=(3,4,5))
Zry2Nb_ND_086=np.loadtxt('ETMT True Stress-Strain Data/086.txt', skiprows=1, delimiter=',', usecols=(3,4,5))
Zry2Nb_ND_089=np.loadtxt('ETMT True Stress-Strain Data/089.txt', skiprows=1, delimiter=',', usecols=(3,4,5))
Zry2Nb_ND_088=np.loadtxt('ETMT True Stress-Strain Data/088.txt', skiprows=1, delimiter=',', usecols=(3,4,5))
Zry2Nb_ND_087=np.loadtxt('ETMT True Stress-Strain Data/087.txt', skiprows=1, delimiter=',', usecols=(3,4,5))

Ti64_ND_066=np.loadtxt('ETMT True Stress-Strain Data/066.txt', skiprows=1, delimiter=',', usecols=(3,4,5))
Ti64_ND_065=np.loadtxt('ETMT True Stress-Strain Data/065.txt', skiprows=1, delimiter=',', usecols=(3,4,5))
Ti64_ND_064=np.loadtxt('ETMT True Stress-Strain Data/064.txt', skiprows=1, delimiter=',', usecols=(3,4,5))
Ti64_ND_071=np.loadtxt('ETMT True Stress-Strain Data/071.txt', skiprows=1, delimiter=',', usecols=(3,4,5))

Ti64_TD_069=np.loadtxt('ETMT True Stress-Strain Data/069.txt', skiprows=1, delimiter=',', usecols=(3,4,5))
Ti64_TD_091=np.loadtxt('ETMT True Stress-Strain Data/091.txt', skiprows=1, delimiter=',', usecols=(3,4,5))
Ti64_TD_070=np.loadtxt('ETMT True Stress-Strain Data/070.txt', skiprows=1, delimiter=',', usecols=(3,4,5))
Ti64_TD_068=np.loadtxt('ETMT True Stress-Strain Data/068.txt', skiprows=1, delimiter=',', usecols=(3,4,5))
Ti64_TD_067=np.loadtxt('ETMT True Stress-Strain Data/067.txt', skiprows=1, delimiter=',', usecols=(3,4,5))

TiSnAl_ND_097=np.loadtxt('ETMT True Stress-Strain Data/097.txt', skiprows=1, delimiter=',', usecols=(3,4,5))
TiSnAl_ND_098=np.loadtxt('ETMT True Stress-Strain Data/098.txt', skiprows=1, delimiter=',', usecols=(3,4,5))
TiSnAl_ND_099=np.loadtxt('ETMT True Stress-Strain Data/099.txt', skiprows=1, delimiter=',', usecols=(3,4,5))

TiSnAl_TD_100=np.loadtxt('ETMT True Stress-Strain Data/100.txt', skiprows=1, delimiter=',', usecols=(3,4,5))
TiSnAl_TD_101=np.loadtxt('ETMT True Stress-Strain Data/101.txt', skiprows=1, delimiter=',', usecols=(3,4,5))

# %%
plt.figure(figsize=(10,9))# decides the size of your plot in inches, useful for reports

plt.rc('xtick',labelsize=20)
plt.rc('ytick',labelsize=20)
plt.rc('legend',fontsize=20)
plt.rc('axes',linewidth=2)
plt.rc('xtick.major',width=2, size=10)
plt.rc('xtick.minor',width=2,size=5)
plt.rc('ytick.major',width=2, size=10)
plt.rc('ytick.minor', width=2, size=5)

plt.minorticks_on()

plt.plot(Zr2Nb_ND_027[:,0],Zr2Nb_ND_027[:,1], linewidth=2, label='650$^\circ$C')
plt.plot(Zr2Nb_ND_025[:,0],Zr2Nb_ND_025[:,1], linewidth=2, label='725$^\circ$C')
plt.plot(Zr2Nb_ND_037[:,0],Zr2Nb_ND_037[:,1], linewidth=2, label='750$^\circ$C')
plt.plot(Zr2Nb_ND_024[:,0],Zr2Nb_ND_024[:,1], linewidth=2, label='800$^\circ$C')
plt.plot(Zr2Nb_ND_028[:,0],Zr2Nb_ND_028[:,1], linewidth=2, label='850$^\circ$C')
plt.plot(Zr2Nb_ND_026[:,0],Zr2Nb_ND_026[:,1], linewidth=2, label='900$^\circ$C')

plt.ylim(0,140)
plt.xlim(-0.01,0.5)

plt.xlabel('True Strain, $\epsilon$ ', fontsize=28)
plt.ylabel('True Stress, $\sigma$ (MPa)', fontsize=28)

#plt.legend()
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

plt.savefig("Zr2Nb_ND.png", bbox_inches='tight')
plt.show() # shows the plot you have asked

# %%
plt.figure(figsize=(10,9))# decides the size of your plot in inches, useful for reports

plt.rc('xtick',labelsize=20)
plt.rc('ytick',labelsize=20)
plt.rc('legend',fontsize=20)
plt.rc('axes',linewidth=2)
plt.rc('xtick.major',width=2, size=10)
plt.rc('xtick.minor',width=2,size=5)
plt.rc('ytick.major',width=2, size=10)
plt.rc('ytick.minor', width=2, size=5)

plt.minorticks_on()

plt.plot(Zr2Nb_TD_033[:,0],Zr2Nb_TD_033[:,1], linewidth=2, label='650$^\circ$C')
plt.plot(Zr2Nb_TD_034[:,0],Zr2Nb_TD_034[:,1], linewidth=2, label='725$^\circ$C')
plt.plot(Zr2Nb_TD_036[:,0],Zr2Nb_TD_036[:,1], linewidth=2, label='750$^\circ$C')
plt.plot(Zr2Nb_TD_035[:,0],Zr2Nb_TD_035[:,1], linewidth=2, label='800$^\circ$C')
plt.plot(Zr2Nb_TD_044[:,0],Zr2Nb_TD_044[:,1], linewidth=2, label='850$^\circ$C')

plt.ylim(0,140)
plt.xlim(-0.01,0.5)

plt.xlabel('True Strain, $\epsilon$ ', fontsize=28)
plt.ylabel('True Stress, $\sigma$ (MPa)', fontsize=28)

#plt.legend()
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

plt.savefig("Zr2Nb_TD.png", bbox_inches='tight')
plt.show() # shows the plot you have asked

# %%
plt.figure(figsize=(10,9))# decides the size of your plot in inches, useful for reports

plt.rc('xtick',labelsize=20)
plt.rc('ytick',labelsize=20)
plt.rc('legend',fontsize=20)
plt.rc('axes',linewidth=2)
plt.rc('xtick.major',width=2, size=10)
plt.rc('xtick.minor',width=2,size=5)
plt.rc('ytick.major',width=2, size=10)
plt.rc('ytick.minor', width=2, size=5)

plt.minorticks_on()

plt.plot(Zry7Nb_ND_029[:,0],Zry7Nb_ND_029[:,1], linewidth=2, label='650$^\circ$C')
plt.plot(Zry7Nb_ND_041[:,0],Zry7Nb_ND_041[:,1], linewidth=2, label='700$^\circ$C')
plt.plot(Zry7Nb_ND_030[:,0],Zry7Nb_ND_030[:,1], linewidth=2, label='725$^\circ$C')
plt.plot(Zry7Nb_ND_031[:,0],Zry7Nb_ND_031[:,1], linewidth=2, label='800$^\circ$C')

plt.ylim(0,300)
plt.xlim(-0.01,0.5)

plt.xlabel('True Strain, $\epsilon$ ', fontsize=28)
plt.ylabel('True Stress, $\sigma$ (MPa)', fontsize=28)

#plt.legend()
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

plt.savefig("Zry7Nb_ND.png", bbox_inches='tight')
plt.show() # shows the plot you have asked

# %%
plt.figure(figsize=(10,9))# decides the size of your plot in inches, useful for reports

plt.rc('xtick',labelsize=20)
plt.rc('ytick',labelsize=20)
plt.rc('legend',fontsize=20)
plt.rc('axes',linewidth=2)
plt.rc('xtick.major',width=2, size=10)
plt.rc('xtick.minor',width=2,size=5)
plt.rc('ytick.major',width=2, size=10)
plt.rc('ytick.minor', width=2, size=5)

plt.minorticks_on()

plt.plot(Zry7Nb_TD_038[:,0],Zry7Nb_TD_038[:,1], linewidth=2, label='650$^\circ$C')
plt.plot(Zry7Nb_TD_039[:,0],Zry7Nb_TD_039[:,1], linewidth=2, label='700$^\circ$C')
plt.plot(Zry7Nb_TD_040[:,0],Zry7Nb_TD_040[:,1], linewidth=2, label='725$^\circ$C')
plt.plot(Zry7Nb_TD_042[:,0],Zry7Nb_TD_042[:,1], linewidth=2, label='800$^\circ$C')

plt.ylim(0,300)
plt.xlim(-0.01,0.5)

plt.xlabel('True Strain, $\epsilon$ ', fontsize=28)
plt.ylabel('True Stress, $\sigma$ (MPa)', fontsize=28)

#plt.legend()
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

plt.savefig("Zry7Nb_TD.png", bbox_inches='tight')
plt.show() # shows the plot you have asked

# %%
plt.figure(figsize=(10,9))# decides the size of your plot in inches, useful for reports

plt.rc('xtick',labelsize=20)
plt.rc('ytick',labelsize=20)
plt.rc('legend',fontsize=20)
plt.rc('axes',linewidth=2)
plt.rc('xtick.major',width=2, size=10)
plt.rc('xtick.minor',width=2,size=5)
plt.rc('ytick.major',width=2, size=10)
plt.rc('ytick.minor', width=2, size=5)

plt.minorticks_on()

plt.plot(Zry2Nb_ND_090[:,0],Zry2Nb_ND_090[:,1], linewidth=2, label='650$^\circ$C')
plt.plot(Zry2Nb_ND_086[:,0],Zry2Nb_ND_086[:,1], linewidth=2, label='700$^\circ$C')
plt.plot(Zry2Nb_ND_089[:,0],Zry2Nb_ND_089[:,1], linewidth=2, label='725$^\circ$C')
plt.plot(Zry2Nb_ND_088[:,0],Zry2Nb_ND_088[:,1], linewidth=2, label='750$^\circ$C')
plt.plot(Zry2Nb_ND_087[:,0],Zry2Nb_ND_087[:,1], linewidth=2, label='800$^\circ$C')

plt.ylim(0,140)
plt.xlim(-0.01,0.5)

plt.xlabel('True Strain, $\epsilon$ ', fontsize=28)
plt.ylabel('True Stress, $\sigma$ (MPa)', fontsize=28)

#plt.legend()
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

plt.savefig("Zry2Nb_ND.png", bbox_inches='tight')
plt.show() # shows the plot you have asked

# %%
plt.figure(figsize=(25,9))# decides the size of your plot in inches, useful for reports

plt.rc('xtick',labelsize=30)
plt.rc('ytick',labelsize=30)
plt.rc('legend',fontsize=20)
plt.rc('axes',linewidth=2)
plt.rc('xtick.major',width=2, size=10)
plt.rc('xtick.minor',width=2,size=5)
plt.rc('ytick.major',width=2, size=10)
plt.rc('ytick.minor', width=2, size=5)

plt.minorticks_on()

#plt.plot(Ti64_ND_064[:,0],Ti64_ND_064[:,1], linewidth=2, label='064 950$^\circ$C')
plt.plot(Ti64_ND_065[:,0],Ti64_ND_065[:,1], linewidth=4, label='065 900$^\circ$C', color='red')
plt.plot(Ti64_ND_066[:,0],Ti64_ND_066[:,1], linewidth=4, label='066 850$^\circ$C',color='blue')
#plt.plot(Ti64_ND_071[:,0],Ti64_ND_071[:,1], linewidth=2, label='071 950$^\circ$C')

plt.ylim(0,140)
plt.xlim(-0.01,0.6)

plt.xlabel('True Strain, $\epsilon$ ', fontsize=38)
plt.ylabel('True Stress, $\sigma$ (MPa)', fontsize=38)

#plt.legend()
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

plt.savefig("Ti64_ND.png", bbox_inches='tight')
plt.show() # shows the plot you have asked

# %%
plt.figure(figsize=(10,9))# decides the size of your plot in inches, useful for reports

plt.rc('xtick',labelsize=20)
plt.rc('ytick',labelsize=20)
plt.rc('legend',fontsize=20)
plt.rc('axes',linewidth=2)
plt.rc('xtick.major',width=2, size=10)
plt.rc('xtick.minor',width=2,size=5)
plt.rc('ytick.major',width=2, size=10)
plt.rc('ytick.minor', width=2, size=5)

plt.minorticks_on()

plt.plot(Ti64_TD_067[:,0],Ti64_TD_067[:,1], linewidth=2, label='067 950$^\circ$C')
plt.plot(Ti64_TD_068[:,0],Ti64_TD_068[:,1], linewidth=2, label='068 900$^\circ$C')
#plt.plot(Ti64_TD_069[:,0],Ti64_TD_069[:,1], linewidth=2, label='069 850$^\circ$C')
plt.plot(Ti64_TD_070[:,0],Ti64_TD_070[:,1], linewidth=2, label='070 900$^\circ$C')
#plt.plot(Ti64_TD_091[:,0],Ti64_TD_091[:,1], linewidth=2, label='091 900$^\circ$C')

#plt.plot(Ti64_TD_069[:,0],Ti64_TD_069[:,1], linewidth=2, label='850$^\circ$C')
#plt.plot(Ti64_TD_091[:,0],Ti64_TD_091[:,1], linewidth=2, label='900$^\circ$C')
#plt.plot(Ti64_TD_070[:,0],Ti64_TD_070[:,1], linewidth=2, label='900$^\circ$C')
#plt.plot(Ti64_TD_068[:,0],Ti64_TD_068[:,1], linewidth=2, label='900$^\circ$C', color='blue')
#plt.plot(Ti64_TD_067[:,0],Ti64_TD_067[:,1], linewidth=2, label='950$^\circ$C',color='red')

plt.ylim(0,140)
plt.xlim(-0.01,0.6)

plt.xlabel('True Strain, $\epsilon$ ', fontsize=28)
plt.ylabel('True Stress, $\sigma$ (MPa)', fontsize=28)

#plt.legend()
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

plt.savefig("Ti64_TD.png",bbox_inches='tight')
plt.show() # shows the plot you have asked

# %%
plt.figure(figsize=(10,9))# decides the size of your plot in inches, useful for reports

plt.rc('xtick',labelsize=20)
plt.rc('ytick',labelsize=20)
plt.rc('legend',fontsize=20)
plt.rc('axes',linewidth=2)
plt.rc('xtick.major',width=2, size=10)
plt.rc('xtick.minor',width=2,size=5)
plt.rc('ytick.major',width=2, size=10)
plt.rc('ytick.minor', width=2, size=5)

plt.minorticks_on()

#plt.plot(TiSnAl_ND_097[:,0],TiSnAl_ND_097[:,1], linewidth=2, label='800$^\circ$C')
plt.plot(TiSnAl_ND_098[:,0],TiSnAl_ND_098[:,1], linewidth=2, label='850$^\circ$C')
plt.plot(TiSnAl_ND_099[:,0],TiSnAl_ND_099[:,1], linewidth=2, label='900$^\circ$C')

plt.ylim(0,200)
plt.xlim(-0.01,0.5)

plt.xlabel('True Strain, $\epsilon$ ', fontsize=28)
plt.ylabel('True Stress, $\sigma$ (MPa)', fontsize=28)

#plt.legend()
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

plt.savefig("TiSnAl_ND.png",bbox_inches='tight')
plt.show() # shows the plot you have asked

# %%
plt.figure(figsize=(10,9))# decides the size of your plot in inches, useful for reports

plt.rc('xtick',labelsize=20)
plt.rc('ytick',labelsize=20)
plt.rc('legend',fontsize=20)
plt.rc('axes',linewidth=2)
plt.rc('xtick.major',width=2, size=10)
plt.rc('xtick.minor',width=2,size=5)
plt.rc('ytick.major',width=2, size=10)
plt.rc('ytick.minor', width=2, size=5)

plt.minorticks_on()

plt.plot(TiSnAl_TD_100[:,0],TiSnAl_TD_100[:,1], linewidth=2, label='800$^\circ$C')
plt.plot(TiSnAl_TD_101[:,0],TiSnAl_TD_101[:,1], linewidth=2, label='850$^\circ$C')

plt.ylim(0,200)
plt.xlim(-0.01,0.5)

plt.xlabel('True Strain, $\epsilon$ ', fontsize=28)
plt.ylabel('True Stress, $\sigma$ (MPa)', fontsize=28)

#plt.legend()
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

plt.savefig("TiSnAl_TD.png",bbox_inches='tight')
plt.show() # shows the plot you have asked

# %%
plt.figure(figsize=(10,9))# decides the size of your plot in inches, useful for reports

plt.rc('xtick',labelsize=20)
plt.rc('ytick',labelsize=20)
plt.rc('legend',fontsize=20)
plt.rc('axes',linewidth=2)
plt.rc('xtick.major',width=2, size=10)
plt.rc('xtick.minor',width=2,size=5)
plt.rc('ytick.major',width=2, size=10)
plt.rc('ytick.minor', width=2, size=5)

plt.minorticks_on()

plt.plot(Zr2Nb_ND_027[:,1],Zr2Nb_ND_027[:,2], linewidth=2, label='650$^\circ$C')
plt.plot(Zr2Nb_ND_025[:,1],Zr2Nb_ND_025[:,2], linewidth=2, label='725$^\circ$C')
plt.plot(Zr2Nb_ND_037[:,1],Zr2Nb_ND_037[:,2], linewidth=2, label='750$^\circ$C')
plt.plot(Zr2Nb_ND_024[:,1],Zr2Nb_ND_024[:,2], linewidth=2, label='800$^\circ$C')
plt.plot(Zr2Nb_ND_028[:,1],Zr2Nb_ND_028[:,2], linewidth=2, label='850$^\circ$C')
plt.plot(Zr2Nb_ND_026[:,1],Zr2Nb_ND_026[:,2], linewidth=2, label='900$^\circ$C')

plt.plot(Zr2Nb_TD_033[:,1],Zr2Nb_TD_033[:,2], linewidth=2, label='650$^\circ$C')
plt.plot(Zr2Nb_TD_034[:,1],Zr2Nb_TD_034[:,2], linewidth=2, label='725$^\circ$C')
plt.plot(Zr2Nb_TD_036[:,1],Zr2Nb_TD_036[:,2], linewidth=2, label='750$^\circ$C')
plt.plot(Zr2Nb_TD_035[:,1],Zr2Nb_TD_035[:,2], linewidth=2, label='800$^\circ$C')
plt.plot(Zr2Nb_TD_044[:,1],Zr2Nb_TD_044[:,2], linewidth=2, label='850$^\circ$C')

plt.plot(Zry7Nb_ND_029[:,1],Zry7Nb_ND_029[:,2], linewidth=2, label='650$^\circ$C')
plt.plot(Zry7Nb_ND_041[:,1],Zry7Nb_ND_041[:,2], linewidth=2, label='700$^\circ$C')
plt.plot(Zry7Nb_ND_030[:,1],Zry7Nb_ND_030[:,2], linewidth=2, label='725$^\circ$C')
plt.plot(Zry7Nb_ND_031[:,1],Zry7Nb_ND_031[:,2], linewidth=2, label='800$^\circ$C')

plt.plot(Zry7Nb_TD_038[:,1],Zry7Nb_TD_038[:,2], linewidth=2, label='650$^\circ$C')
plt.plot(Zry7Nb_TD_039[:,1],Zry7Nb_TD_039[:,2], linewidth=2, label='700$^\circ$C')
plt.plot(Zry7Nb_TD_040[:,1],Zry7Nb_TD_040[:,2], linewidth=2, label='725$^\circ$C')
plt.plot(Zry7Nb_TD_042[:,1],Zry7Nb_TD_042[:,2], linewidth=2, label='800$^\circ$C')

plt.plot(Zry2Nb_ND_090[:,1],Zry2Nb_ND_090[:,2], linewidth=2, label='650$^\circ$C')
#plt.plot(Zry2Nb_ND_086[:,1],Zry2Nb_ND_086[:,2], linewidth=2, label='700$^\circ$C')
plt.plot(Zry2Nb_ND_089[:,1],Zry2Nb_ND_089[:,2], linewidth=2, label='725$^\circ$C')
plt.plot(Zry2Nb_ND_088[:,1],Zry2Nb_ND_088[:,2], linewidth=2, label='750$^\circ$C')
plt.plot(Zry2Nb_ND_087[:,1],Zry2Nb_ND_087[:,2], linewidth=2, label='800$^\circ$C')

plt.plot(Ti64_ND_066[:,1],Ti64_ND_066[:,2], linewidth=2, label='850$^\circ$C')
plt.plot(Ti64_ND_065[:,1],Ti64_ND_065[:,2], linewidth=2, label='900$^\circ$C')
plt.plot(Ti64_ND_064[:,1],Ti64_ND_064[:,2], linewidth=2, label='950$^\circ$C')
#plt.plot(Ti64_ND_071[:,1],Ti64_ND_071[:,2], linewidth=2, label='950$^\circ$C')

#plt.plot(Ti64_TD_069[:,1],Ti64_TD_069[:,2], linewidth=2, label='850$^\circ$C')
#plt.plot(Ti64_TD_091[:,1],Ti64_TD_091[:,2], linewidth=2, label='900$^\circ$C')
plt.plot(Ti64_TD_070[:,1],Ti64_TD_070[:,2], linewidth=2, label='900$^\circ$C')
plt.plot(Ti64_TD_068[:,1],Ti64_TD_068[:,2], linewidth=2, label='900$^\circ$C')
plt.plot(Ti64_TD_067[:,1],Ti64_TD_067[:,2], linewidth=2, label='950$^\circ$C')

#plt.plot(TiSnAl_ND_097[:,1],TiSnAl_ND_097[:,2], linewidth=2, label='800$^\circ$C')
plt.plot(TiSnAl_ND_098[:,1],TiSnAl_ND_098[:,2], linewidth=2, label='850$^\circ$C')
plt.plot(TiSnAl_ND_099[:,1],TiSnAl_ND_099[:,2], linewidth=2, label='900$^\circ$C')

plt.plot(TiSnAl_TD_100[:,1],TiSnAl_TD_100[:,2], linewidth=2, label='800$^\circ$C')
plt.plot(TiSnAl_TD_101[:,1],TiSnAl_TD_101[:,2], linewidth=2, label='850$^\circ$C')

plt.ylim(880,920)
plt.xlim(0,300)

plt.xlabel('Stress, $\sigma$ (MPa) ', fontsize=28)
plt.ylabel('Temperature, $\sigma$ (MPa)', fontsize=28)

#plt.legend()
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

plt.savefig("TiSnAl_TD.png",bbox_inches='tight')
plt.show() # shows the plot you have asked

# %%
plt.figure(figsize=(10,8))# decides the size of your plot in inches, useful for reports

plt.rc('xtick',labelsize=20)
plt.rc('ytick',labelsize=20)
plt.rc('legend',fontsize=20)
plt.rc('axes',linewidth=2)
plt.rc('xtick.major',width=2, size=10)
plt.rc('xtick.minor',width=2,size=5)
plt.rc('ytick.major',width=2, size=10)
plt.rc('ytick.minor', width=2, size=5)

plt.minorticks_on()


plt.plot(Zry2Nb_ND_089[:,0],Zry2Nb_ND_089[:,1], linewidth=4, label='Zr-2.5Nb, 725$^\circ$C')
plt.plot(Zry2Nb_ND_087[:,0],Zry2Nb_ND_087[:,1], linewidth=4, label='Zr-2.5Nb, 800$^\circ$C')
# plt.plot(Zry7Nb_ND_041[:,0],Zry7Nb_ND_041[:,1], linewidth=4, label='Zry-4 + 7 wt.% Nb, 700$^\circ$C')
# plt.plot(Ti64_ND_065[:,0],Ti64_ND_065[:,1], linewidth=4, label='Ti-6Al-4V, 900$^\circ$C')

plt.ylim(0,140)
plt.xlim(-0.01,0.55)

plt.xlabel('True Strain, $\epsilon$ ', fontsize=28)
plt.ylabel('True Stress, $\sigma$ (MPa)', fontsize=28)

#plt.legend()
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

plt.savefig("Mixed_ReX&GG_1.png", bbox_inches='tight')
plt.show() # shows the plot you have asked
